# %%
import os
import numpy as np
import pandas as pd
import gensim
from scipy.sparse import find
import tensorflow as tf
import random
import time
import datetime
import re
import MeCab

from jamo import h2j, j2hcj
import gc
# Out:
# c:\users\yejinlee\anaconda3\envs\emotion\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
mecab = MeCab.Tagger()

# %%
def load_w2v_dic (path, flag, w2v_size,filetype):
    allFileNames = os.listdir(path)
    modelNames = [fn for fn in allFileNames if fn.find(flag+'.'+filetype) > -1 and fn.find(str(w2v_size)) > -1]
    
    model = gensim.models.Word2Vec.load(path+'/'+modelNames[0])
    print(modelNames[0]+' is loaded')
    return model

# %%
# Out:
# Object `pd.drop` not found.

# %%
#data별로 처리가 다름
dataDir = 'data/uplusInput/train'
allFileNames = os.listdir(dataDir)

filePaths = []

for fname in allFileNames:
    if fname[0] != '.':
        filePaths.append(os.path.join(dataDir, fname))


for fpn in filePaths:
    if fpn[-4:] == '.csv':
        datas = pd.read_csv(fpn)
        input_x = datas['content']
        y_train = datas[['neg','neu','pos']]

# %%
def make_output(points, threshold_low, threshold_high):
    results = np.zeros((len(points),3))
    neu_candi_idx = []
    for idx, point in enumerate(points):
        if point < threshold_low:
            results[idx,0] = 1
        elif point > threshold_high:  
            results[idx,2] = 1
        else:
            #return [0,0,0]
            neu_candi_idx.append(idx)
#             results[idx,1] = 1
    results = np.delete(results, neu_candi_idx, 0)
#     print(neu_candi_idx)
    return results, neu_candi_idx

# %%
targetDir = 'data/movieReview/formmated'
allFileNames = os.listdir(targetDir)
filesize = len(allFileNames)

testSize = int(filesize/20)
subNames = allFileNames[0:testSize]
# print(subNames)

for fname in subNames:
    if fname[0] != '.':
        data_path = os.path.join(targetDir, fname)

        try:
            corpus = pd.read_csv(data_path, quotechar="'", header=None, encoding="utf-8", )
            contents = corpus[5][:]
            

            rank = corpus[2][:]
            temp_y, remove_index = make_output(rank, 5.5,7.5) #수정중
#             remove_index = np.where(temp_y[:,1]==1)
            contents = contents.drop(remove_index)

            input_x = pd.concat([input_x, contents], ignore_index=True)
            y_train = pd.concat([y_train, pd.DataFrame(temp_y, columns=['neg','neu','pos'])], ignore_index=True)

        except Exception as e:
            print(fname + ' : ' + str(e))

            pass

# %%
print(len(y_train))
print(sum(y_train['neg']==1))
print(sum(y_train['neu']==1))
print(sum(y_train['pos']==1))
# Out:
# 424103
# 73292
# 2847
# 347964

# %%
input_x.shape
# Out:
# (424103,)

# %%
temp_pos_x = input_x[y_train['pos']==1][:10000]
temp_pos_y = y_train[y_train['pos']==1][:10000]

temp_neg_x = input_x[y_train['neg']==1][:10000]
temp_neg_y = y_train[y_train['neg']==1][:10000]

temp_neu_x = input_x[y_train['neu']==1]
temp_neu_y = y_train[y_train['neu']==1]

input_x = pd.concat([temp_pos_x, temp_neg_x, temp_neu_x], ignore_index=True)

y_train = pd.concat([temp_pos_y, temp_neg_y, temp_neu_y], ignore_index=True)

# %%
input_x.shape
# Out:
# (22847,)

# %%
dataDir = 'data/uplusInput/test'
allFileNames = os.listdir(dataDir)

filePaths = []

for fname in allFileNames:
    if fname[0] != '.':
        filePaths.append(os.path.join(dataDir, fname))


for fpn in filePaths:
    if fpn[-4:] == '.csv':
        datas = pd.read_csv(fpn)
        test_input_x = datas['content']
        y_test = datas[['neg','neu','pos']]

# %%
####################################################
# divide train/test set function                   #
####################################################
def divide(x, y, train_prop):
    random.seed(1234)
#     x = np.array(x)
#     y = np.array(y)
    tmp = np.random.permutation(np.arange(len(x)))
    return x[tmp][:round(train_prop * len(x))],  x[tmp][-(len(x)-round(train_prop * len(x))):], y[tmp][:round(train_prop * len(x))], y[tmp][-(len(x)-round(train_prop * len(x))):]
#     x_tr = x[tmp][:round(train_prop * len(x))]
#     y_tr = y[tmp][:round(train_prop * len(x))]
#     x_te = x[tmp][-(len(x)-round(train_prop * len(x))):]
#     y_te = y[tmp][-(len(x)-round(train_prop * len(x))):]
#     return x_tr, x_te, y_tr, y_te

# %%
def find_vector(word_array, word_vectors, word2vector_size=300):
    embedding_vector = []
    for w in word_array:
        if w not in word_vectors.vocab:
            embedding_vector.append(np.random.normal(scale=1e-2, size=word2vector_size))#[np.zeros(shape=300)] #
        else:
            embedding_vector.append(word_vectors[w])
    return embedding_vector

# %%
def batch_iter(x_train, y_train, batch_size, num_epochs, shuffle=True):
    """
    Generates a batch iterator for a dataset.
    """
    x_train = np.array(x_train)
    y_train = np.array(y_train)
    data_size = len(x_train)
    num_batches_per_epoch = int((data_size - 1) / batch_size) + 1
    for epoch in range(num_epochs):
        # Shuffle the data at each epoch
        if shuffle:
            shuffle_indices = np.random.permutation(np.arange(data_size))
            shuffled_x_data = x_train[shuffle_indices]
            shuffled_y_data = y_train[shuffle_indices]
        else:
            suffled_x_data = x_train
            shuffled_y_data = y_train
            
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, data_size)
            yield zip(shuffled_x_data[start_index:end_index], shuffled_y_data[start_index:end_index])

# %%
word2vector_size = 150
window = 5  #현재 word를 계산하는데 사용하는 maximum distance ?
min_count = 2 #단어가 해당 개수 이하로 나오면 무시
SAVE_PATH = './wordDic/'
flag1 = 'WT'

model1 = load_w2v_dic(path=SAVE_PATH, flag=flag1, w2v_size = word2vector_size,filetype='bin')
word_vectors_WT = model1.wv

flag2 = 'JM'
model2 = load_w2v_dic(path=SAVE_PATH, flag=flag2, w2v_size = word2vector_size,filetype='bin')
word_vectors_JM = model2.wv

w2v_params = {
    "word2vector_size" : 150,
    "window" : 5,
    "min_count" : 2,
    "flag1" : 'WT',
    "flag2" : 'JM'
}
# Out:
# 201804231620_150_WT.bin is loaded
# 201804231704_150_JM.bin is loaded

# %%
w2v_params["window"]
# Out:
# 5

# %%
#flag define
max_seq_size = 150
filter_sizes = [2, 3]
num_filters = [128, 128]

input_weights = [1,0.5]
dropout_keep_prob = 0.7
l2_reg_lambda = 0.1

batch_size = 32
num_epochs = 5000
evaluate_every = 200
checkpoint_every = 200
num_checkpoints = 5

allow_soft_placement = True
log_device_placement = False

# %%
# input_x_vec1 = []
# input_x_vec2 = []

# w2v1 = Word2Vec(word_vec_size=word2vector_size, window=window, min_count=min_count, flag=flag1)
# w2v2 = Word2Vec(word_vec_size=word2vector_size, window=window, min_count=min_count, flag=flag2)

# for x in input_x:
#     parse_x1 = w2v1.make_input([x]) #WT
#     parse_x2 = w2v2.make_input([x]) #L1
#     embedding_vec1 = find_vector(parse_x1, word_vectors_WT, word2vector_size)
#     embedding_vec2 = find_vector(parse_x2, word_vectors_JM, word2vector_size)
    
#     temp_len1 = max_seq_size-len(embedding_vec1)
#     temp_len2 = max_seq_size-len(embedding_vec2)
    
#     if temp_len1 > 0:
#         for i in range(0,temp_len1):
#             embedding_vec1 += [np.zeros(word2vector_size)]    
#     else:
#         embedding_vec1 = embedding_vec1[:max_seq_size]
        
#     if temp_len2 > 0:
#         for i in range(0,temp_len2):
#             embedding_vec2 += [np.zeros(word2vector_size)]    
#     else:
#         embedding_vec2 = embedding_vec2[:max_seq_size]    
    
#     input_x_vec1.append(embedding_vec1)
#     input_x_vec2.append(embedding_vec2)

# del input_x

# %%
# test_input_x_vec1 = []
# test_input_x_vec2 = []

# # w2v = Word2Vec(word_vec_size=word2vector_size, window=window, min_count=min_count, flag=flag)

# for x in test_input_x:
#     parse_x1 = w2v1.make_input([x]) #WT
#     parse_x2 = w2v2.make_input([x]) #JM
#     embedding_vec1 = find_vector(parse_x1, word_vectors_WT, word2vector_size)
#     embedding_vec2 = find_vector(parse_x2, word_vectors_JM, word2vector_size)
    
#     temp_len1 = max_seq_size-len(embedding_vec1)
#     temp_len2 = max_seq_size-len(embedding_vec2)
    
#     if temp_len1 > 0:
#         for i in range(0,temp_len1):
#             embedding_vec1 += [np.zeros(word2vector_size)]    
#     else:
#         embedding_vec1 = embedding_vec1[:max_seq_size]
        
#     if temp_len2 > 0:
#         for i in range(0,temp_len2):
#             embedding_vec2 += [np.zeros(word2vector_size)]    
#     else:
#         embedding_vec2 = embedding_vec2[:max_seq_size]    
    
#     test_input_x_vec1.append(embedding_vec1)
#     test_input_x_vec2.append(embedding_vec2)

# del test_input_x
# del w2v1
# del w2v2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-71836fb59567> in <module>()
#       5
#       6 for x in test_input_x:
# ----> 7     parse_x1 = w2v1.make_input([x]) #WT
#       8     parse_x2 = w2v2.make_input([x]) #JM
#       9     embedding_vec1 = find_vector(parse_x1, word_vectors_WT, word2vector_size)
#
# NameError: name 'w2v1' is not defined

# %%
# x_train1 = np.array(input_x_vec1)
# x_train2 = np.array(input_x_vec2)
# del input_x_vec1
# del input_x_vec2

# x_test1 = np.array(test_input_x_vec1)
# x_test2 = np.array(test_input_x_vec2)
# del test_input_x_vec1
# del test_input_x_vec2

# y_train = np.array(y_train)
# y_test = np.array(y_test)

# del model1
# del model2
# del word_vectors_WT
# del word_vectors_JM

# %%
# del input_x_vec
# del test_input_x_vec 
# del input_x
# del test_input_x
# del w2v
# del model
# del word_vectors

# %%
# divide dataset into train/test set - 하나의 문서를 나눠서 사용할때
# x_train, x_test, y_train, y_test = divide(np.array(input_x_vec),np.array(input_y),train_prop=1)

# %%
class TextCNN(object):
    """
    A CNN for text classification.
    Uses an embedding layer, followed by a convolutional, max-pooling and softmax layer.
    <Parameters>
        - sequence_length: 최대 문장 길이
        - num_classes: 클래스 개수
        - embedding_size: 각 단어에 해당되는 임베디드 벡터의 차원
        - filter_sizes: convolutional filter들의 사이즈 (= 각 filter가 몇 개의 단어를 볼 것인가?) (예: "3, 4, 5")
        - num_filters: 각 filter size 별 filter 수
        - l2_reg_lambda: 각 weights, biases에 대한 l2 regularization 정도
    """
    def make_filter_set(self, filter_size, num_filters):
        if type(filter_size) == int:
            filter_size = [filter_size]
        if type(num_filters) == int:
            num_filters = [num_filters]

        filter_first = True
        if len(filter_size) >= len(num_filters):
            t1 = filter_size
            t2 = num_filters
        else:
            t1 = num_filters
            t2 = filter_size
            filter_first = False

        result_arr = []

        for i, t in enumerate(t1):
            j = i

            if i >= len(t2):
                j = i%len(t2)

            if filter_first:
                c = (t , t2[j])
            else:
                c = (t2[j], t)

            result_arr.append(c)

        return result_arr
        
    def __init__(
            self, sequence_length, num_classes, 
            embedding_size, filter_sizes, num_filters, l2_reg_lambda=0.0, input_weights=[1.0]):
       
        # Placeholders for input, output and dropout
        
        
        self.input_x1 = tf.placeholder(tf.float32, [None, sequence_length, embedding_size], name="input_x1")
        self.input_x2 = tf.placeholder(tf.float32, [None, sequence_length, embedding_size], name="input_x2")
        input_x = [self.input_x1 , self.input_x2]
        
        self.input_y = tf.placeholder(tf.float32, [None, num_classes], name="input_y")
        self.dropout_keep_prob = tf.placeholder(tf.float32, name="dropout_keep_prob")

        # Keeping track of l2 regularization loss (optional)
        l2_loss = tf.constant(0.0)

#         self.expended_input_x = tf.expand_dims(self.input_x, -1) #conv2를 위한 차원 expend?
        test_set = self.make_filter_set(filter_size=filter_sizes,num_filters=num_filters)
        
        # Create a convolution + maxpool layer for each filter size
        num_filters_total = 0
        pooled_outputs = []
        
        for idx, filter_set in enumerate(test_set):
            filter_size, num_filter = filter_set
            with tf.name_scope("conv-%s" % filter_size):
                
                input_vec = tf.expand_dims(input_x[idx], -1) 
                
                sentence_length = int(input_vec.shape[1])
                word_vector_size = int(input_vec.shape[2])
                
                # Convolution Layer
                filter_shape = [filter_size, word_vector_size, 1, num_filter]
                print("filter shape : "+str(filter_shape))

                W = tf.Variable(tf.truncated_normal(filter_shape), name="W") #변경 가능 영역 - stddev / truncated_normal<->random_normal
                b = tf.Variable(tf.random_normal(shape=[num_filter]), name="b")
                conv = tf.nn.conv2d(
                    input_vec,
                    W,
                    strides=[1, 1, 1, 1],
                    padding="VALID",
                    name="conv")
                # Apply nonlinearity
                h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")
                print("conv result shape : "+str(h.shape))
                
            with tf.name_scope("maxpool-%s" % filter_size):
                # Maxpooling over the outputs
                sentence_length = int(h.shape[1])
                word2vec_size = int(h.shape[2])
                
                pool_size = [1, sentence_length, word2vec_size, 1]
                print("pool size : "+ str(pool_size))
                pooled = tf.nn.max_pool(
                    h,
                    ksize=pool_size,
                    strides=[1,1,1,1],
                    padding='VALID',
                    name="pool")
                print("pooled shape : "+ str(pooled.shape))
                pooled = input_weights[idx] * pooled
                pooled_outputs.append(pooled)
                num_filters_total += num_filter

        with tf.name_scope("dropout"):
            self.h_pool = tf.concat(axis=3, values=pooled_outputs)
            self.h_pool_flat = tf.reshape(self.h_pool, [-1, num_filters_total])
            self.h_drop = tf.nn.dropout(self.h_pool_flat, self.dropout_keep_prob)
            
        # Final (unnormalized) scores and predictions
        with tf.name_scope("output"):
            W = tf.get_variable(
                "W",
                shape=[num_filters_total, num_classes],
                initializer=tf.contrib.layers.xavier_initializer())
            b = tf.Variable(tf.constant(0.1, shape=[num_classes]), name="b")
            l2_loss += tf.nn.l2_loss(W)
            l2_loss += tf.nn.l2_loss(b)
            self.scores = tf.nn.xw_plus_b(self.h_drop, W, b, name="scores")
            self.predictions = tf.argmax(self.scores, 1, name="predictions")

        # Calculate Mean cross-entropy loss
        with tf.name_scope("loss"):
            losses =tf.nn.softmax_cross_entropy_with_logits_v2(labels=self.input_y, logits=self.scores)
            self.loss = tf.reduce_mean(losses) + l2_reg_lambda * l2_loss

        # Accuracy
        with tf.name_scope("accuracy"):
            correct_predictions = tf.equal(self.predictions, tf.argmax(self.input_y, 1))
            self.accuracy = tf.reduce_mean(tf.cast(correct_predictions, "float"), name="accuracy")

# %%
def input_changes(x_input, w2v_params):
    input_x_vec1 = []
    input_x_vec2 = []
    
    w2v1 = Word2Vec(word_vec_size=w2v_params["word2vector_size"], window=w2v_params["window"], min_count=w2v_params["min_count"], flag=w2v_params["flag1"])
    w2v2 = Word2Vec(word_vec_size=w2v_params["word2vector_size"], window=w2v_params["window"], min_count=w2v_params["min_count"], flag=w2v_params["flag2"])

    for x in x_input:
        parse_x1 = w2v1.make_input([x]) #WT
        parse_x2 = w2v2.make_input([x]) #L1
        embedding_vec1 = find_vector(parse_x1, word_vectors_WT, word2vector_size)
        embedding_vec2 = find_vector(parse_x2, word_vectors_JM, word2vector_size)

        temp_len1 = max_seq_size-len(embedding_vec1)
        temp_len2 = max_seq_size-len(embedding_vec2)

        if temp_len1 > 0:
            for i in range(0,temp_len1):
                embedding_vec1 += [np.zeros(word2vector_size)]    
        else:
            embedding_vec1 = embedding_vec1[:max_seq_size]

        if temp_len2 > 0:
            for i in range(0,temp_len2):
                embedding_vec2 += [np.zeros(word2vector_size)]    
        else:
            embedding_vec2 = embedding_vec2[:max_seq_size]    

        input_x_vec1.append(embedding_vec1)
        input_x_vec2.append(embedding_vec2)
    return np.array(input_x_vec1) , np.array(input_x_vec2)

# %%
print(type(input_x))
print(type(y_train))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# 3. train the model and test
with tf.Graph().as_default():
    sess = tf.Session()
    with sess.as_default():
        with tf.device('/cpu:0'):
            cnn = TextCNN(sequence_length=max_seq_size,
                          num_classes=y_train.shape[1],
                          embedding_size=word2vector_size,
                          filter_sizes=filter_sizes,
                          num_filters=num_filters,
                          l2_reg_lambda=l2_reg_lambda,
                          input_weights=input_weights)

            # Define Training procedure
            global_step = tf.Variable(0, name="global_step", trainable=False)
            optimizer = tf.train.AdamOptimizer(1e-3)
            grads_and_vars = optimizer.compute_gradients(cnn.loss)
            train_op = optimizer.apply_gradients(grads_and_vars, global_step=global_step)

            # Keep track of gradient values and sparsity (optional)
    #         grad_summaries = []
    #         for g, v in grads_and_vars:
    #             if g is not None:
    #                 grad_hist_summary = tf.summary.histogram("{}".format(v.name), g)
    #                 sparsity_summary = tf.summary.scalar("{}".format(v.name), tf.nn.zero_fraction(g))
    #                 grad_summaries.append(grad_hist_summary)
    #                 grad_summaries.append(sparsity_summary)
    #         grad_summaries_merged = tf.summary.merge(grad_summaries)

            # Output directory for models and summaries
            timestamp = str(int(time.time()))
            out_dir = os.path.abspath(os.path.join(os.path.curdir, "runs", timestamp))
            print("Writing to {}\n".format(out_dir))

            # Summaries for loss and accuracy
            loss_summary = tf.summary.scalar("loss", cnn.loss)
            acc_summary = tf.summary.scalar("accuracy", cnn.accuracy)

            # Train Summaries
            train_summary_op = tf.summary.merge([loss_summary, acc_summary])#, grad_summaries_merged])
            train_summary_dir = os.path.join(out_dir, "summaries", "train")
            train_summary_writer = tf.summary.FileWriter(train_summary_dir, sess.graph)

            # Dev summaries
            dev_summary_op = tf.summary.merge([loss_summary, acc_summary])
            dev_summary_dir = os.path.join(out_dir, "summaries", "dev")
            dev_summary_writer = tf.summary.FileWriter(dev_summary_dir, sess.graph)

            # Checkpoint directory. Tensorflow assumes this directory already exists so we need to create it
            checkpoint_dir = os.path.abspath(os.path.join(out_dir, "checkpoints"))
            checkpoint_prefix = os.path.join(checkpoint_dir, "model")
            if not os.path.exists(checkpoint_dir):
                os.makedirs(checkpoint_dir)
            saver = tf.train.Saver(tf.global_variables(), max_to_keep=num_checkpoints)

            # Initialize all variables

            sess.run(tf.global_variables_initializer())
            
            def train_step(x_input, y_batch, w2v_params):
                """
                A single training step
                """
                x_batch1, x_batch2 = input_changes(x_input, w2v_params)
                feed_dict = {
                    cnn.input_x1: x_batch1,
                    cnn.input_x2: x_batch2,
                    cnn.input_y: y_batch,
                    cnn.dropout_keep_prob:dropout_keep_prob
                }
                try:
                    _, step, summaries, loss, accuracy = sess.run(
                        [train_op, global_step, train_summary_op, cnn.loss, cnn.accuracy],
                        feed_dict)
    #                 time_str = datetime.datetime.now().isoformat()
    #                 print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
                    train_summary_writer.add_summary(summaries, step)
                except Exception as e:
                    print(e)

            def dev_step(x_input, y_batch, w2v_params, writer=None):
                """
                Evaluates model on a dev set
                """
                x_batch1, x_batch2 = input_changes(x_input, w2v_params)
                
                feed_dict = {
                    cnn.input_x1: x_batch1,
                    cnn.input_x2: x_batch2,
                    cnn.input_y: y_batch,
                    cnn.dropout_keep_prob: 1.0
                }
                step, summaries, loss, accuracy = sess.run(
                    [global_step, dev_summary_op, cnn.loss, cnn.accuracy],
                    feed_dict)
                time_str = datetime.datetime.now().isoformat()
                print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
                if writer:
                    writer.add_summary(summaries, step)

            # Generate batches
            batches = batch_iter(input_x, y_train,  batch_size, num_epochs)

            testpoint = 0
            # Training loop. For each batch...
            for batch in batches:
                gc.collect() #memory 문제가...
                x_batch, y_batch = zip(*batch)
                train_step(x_batch, y_batch,  w2v_params=w2v_params)
                current_step = tf.train.global_step(sess, global_step)
                if current_step % evaluate_every == 0:
                    print("\nEvaluation:")
                    dev_step(test_input_x, y_test, writer=dev_summary_writer, w2v_params=w2v_params)
                    print("")
                if current_step % checkpoint_every == 0:
                    path = saver.save(sess, checkpoint_prefix, global_step=current_step)
                    print("Saved model checkpoint to {}\n".format(path))
# Out:
# filter shape : [2, 150, 1, 128]
# conv result shape : (?, 149, 1, 128)
# pool size : [1, 149, 1, 1]
# pooled shape : (?, 1, 1, 128)
# filter shape : [3, 150, 1, 128]
# conv result shape : (?, 148, 1, 128)
# pool size : [1, 148, 1, 1]
# pooled shape : (?, 1, 1, 128)
# Writing to D:\emotionTest\runs\1526617599
#
#
# Evaluation:
# 2018-05-18T13:27:30.896302: step 200, loss 6.36656, acc 0.54
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-200
#
#
# Evaluation:
# 2018-05-18T13:28:15.069468: step 400, loss 2.63543, acc 0.72
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-400
#
#
# Evaluation:
# 2018-05-18T13:28:59.230013: step 600, loss 2.90794, acc 0.59
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-600
#
#
# Evaluation:
# 2018-05-18T13:29:37.333532: step 800, loss 0.987124, acc 0.77
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-800
#
#
# Evaluation:
# 2018-05-18T13:30:22.057897: step 1000, loss 1.32928, acc 0.69
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-1000
#
#
# Evaluation:
# 2018-05-18T13:31:08.923260: step 1200, loss 1.28201, acc 0.61
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-1200
#
#
# Evaluation:
# 2018-05-18T13:31:53.956617: step 1400, loss 0.88562, acc 0.77
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-1400
#
#
# Evaluation:
# 2018-05-18T13:32:38.347779: step 1600, loss 1.21341, acc 0.63
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-1600
#
#
# Evaluation:
# 2018-05-18T13:33:22.938934: step 1800, loss 0.697599, acc 0.78
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-1800
#
#
# Evaluation:
# 2018-05-18T13:34:08.128305: step 2000, loss 0.82466, acc 0.71
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-2000
#
#
# Evaluation:
# 2018-05-18T13:34:53.021033: step 2200, loss 1.10495, acc 0.57
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-2200
#
#
# Evaluation:
# 2018-05-18T13:35:37.866199: step 2400, loss 0.714362, acc 0.73
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-2400
#
#
# Evaluation:
# 2018-05-18T13:36:26.090376: step 2600, loss 1.22829, acc 0.56
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-2600
#
#
# Evaluation:
# 2018-05-18T13:37:12.235943: step 2800, loss 0.476205, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-2800
#
#
# Evaluation:
# 2018-05-18T13:37:57.704114: step 3000, loss 0.854256, acc 0.79
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-3000
#
#
# Evaluation:
# 2018-05-18T13:38:43.537681: step 3200, loss 0.423596, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-3200
#
#
# Evaluation:
# 2018-05-18T13:39:28.088231: step 3400, loss 0.457719, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-3400
#
#
# Evaluation:
# 2018-05-18T13:40:14.245808: step 3600, loss 0.8183, acc 0.67
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-3600
#
#
# Evaluation:
# 2018-05-18T13:40:58.173750: step 3800, loss 0.781119, acc 0.7
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-3800
#
#
# Evaluation:
# 2018-05-18T13:41:41.575290: step 4000, loss 0.692655, acc 0.69
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-4000
#
#
# Evaluation:
# 2018-05-18T13:42:24.975218: step 4200, loss 0.359163, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-4200
#
#
# Evaluation:
# 2018-05-18T13:43:08.412166: step 4400, loss 0.819719, acc 0.66
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-4400
#
#
# Evaluation:
# 2018-05-18T13:43:51.834509: step 4600, loss 0.368042, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-4600
#
#
# Evaluation:
# 2018-05-18T13:44:35.200861: step 4800, loss 0.631645, acc 0.7
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-4800
#
#
# Evaluation:
# 2018-05-18T13:45:18.690812: step 5000, loss 0.359591, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-5000
#
#
# Evaluation:
# 2018-05-18T13:46:02.340577: step 5200, loss 0.522924, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-5200
#
#
# Evaluation:
# 2018-05-18T13:46:45.883919: step 5400, loss 0.36725, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-5400
#
#
# Evaluation:
# 2018-05-18T13:47:29.288071: step 5600, loss 0.446928, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-5600
#
#
# Evaluation:
# 2018-05-18T13:48:12.786595: step 5800, loss 0.357579, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-5800
#
#
# Evaluation:
# 2018-05-18T13:48:56.198545: step 6000, loss 0.451337, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-6000
#
#
# Evaluation:
# 2018-05-18T13:49:39.565696: step 6200, loss 0.530244, acc 0.78
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-6200
#
#
# Evaluation:
# 2018-05-18T13:50:22.878826: step 6400, loss 0.628157, acc 0.7
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-6400
#
#
# Evaluation:
# 2018-05-18T13:51:06.484985: step 6600, loss 0.433976, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-6600
#
#
# Evaluation:
# 2018-05-18T13:51:49.861533: step 6800, loss 0.83566, acc 0.71
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-6800
#
#
# Evaluation:
# 2018-05-18T13:52:33.165464: step 7000, loss 0.414093, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-7000
#
#
# Evaluation:
# 2018-05-18T13:53:16.487598: step 7200, loss 0.641144, acc 0.71
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-7200
#
#
# Evaluation:
# 2018-05-18T13:53:59.811138: step 7400, loss 0.852466, acc 0.65
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-7400
#
#
# Evaluation:
# 2018-05-18T13:54:43.078067: step 7600, loss 0.324507, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-7600
#
#
# Evaluation:
# 2018-05-18T13:55:26.325008: step 7800, loss 0.328387, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-7800
#
#
# Evaluation:
# 2018-05-18T13:56:11.157962: step 8000, loss 0.391189, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-8000
#
#
# Evaluation:
# 2018-05-18T13:56:54.457320: step 8200, loss 0.346114, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-8200
#
#
# Evaluation:
# 2018-05-18T13:57:37.805262: step 8400, loss 0.412483, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-8400
#
#
# Evaluation:
# 2018-05-18T13:58:21.240399: step 8600, loss 0.424307, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-8600
#
#
# Evaluation:
# 2018-05-18T13:59:04.639736: step 8800, loss 0.597327, acc 0.75
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-8800
#
#
# Evaluation:
# 2018-05-18T13:59:48.011891: step 9000, loss 0.368727, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-9000
#
#
# Evaluation:
# 2018-05-18T14:00:31.387637: step 9200, loss 0.287264, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-9200
#
#
# Evaluation:
# 2018-05-18T14:01:14.835373: step 9400, loss 0.334168, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-9400
#
#
# Evaluation:
# 2018-05-18T14:01:58.255509: step 9600, loss 0.304928, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-9600
#
#
# Evaluation:
# 2018-05-18T14:02:41.591248: step 9800, loss 0.40778, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-9800
#
#
# Evaluation:
# 2018-05-18T14:03:25.072397: step 10000, loss 0.53194, acc 0.78
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-10000
#
#
# Evaluation:
# 2018-05-18T14:04:08.448750: step 10200, loss 0.307203, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-10200
#
#
# Evaluation:
# 2018-05-18T14:04:51.827681: step 10400, loss 0.270373, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-10400
#
#
# Evaluation:
# 2018-05-18T14:05:35.093623: step 10600, loss 0.460379, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-10600
#
#
# Evaluation:
# 2018-05-18T14:06:18.708559: step 10800, loss 0.561258, acc 0.76
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-10800
#
#
# Evaluation:
# 2018-05-18T14:07:02.184702: step 11000, loss 0.302268, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-11000
#
#
# Evaluation:
# 2018-05-18T14:07:45.565250: step 11200, loss 0.311502, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-11200
#
#
# Evaluation:
# 2018-05-18T14:08:29.087198: step 11400, loss 0.529842, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-11400
#
#
# Evaluation:
# 2018-05-18T14:09:12.629552: step 11600, loss 0.368464, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-11600
#
#
# Evaluation:
# 2018-05-18T14:09:56.202701: step 11800, loss 0.324498, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-11800
#
#
# Evaluation:
# 2018-05-18T14:10:39.483459: step 12000, loss 0.374336, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-12000
#
#
# Evaluation:
# 2018-05-18T14:11:23.096412: step 12200, loss 0.380086, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-12200
#
#
# Evaluation:
# 2018-05-18T14:12:06.561951: step 12400, loss 0.363283, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-12400
#
#
# Evaluation:
# 2018-05-18T14:12:50.134105: step 12600, loss 0.36008, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-12600
#
#
# Evaluation:
# 2018-05-18T14:13:33.629835: step 12800, loss 0.305198, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-12800
#
#
# Evaluation:
# 2018-05-18T14:14:17.147205: step 13000, loss 0.328533, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-13000
#
#
# Evaluation:
# 2018-05-18T14:15:00.553737: step 13200, loss 0.442281, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-13200
#
#
# Evaluation:
# 2018-05-18T14:15:44.195683: step 13400, loss 0.389001, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-13400
#
#
# Evaluation:
# 2018-05-18T14:16:27.706807: step 13600, loss 0.412388, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-13600
#
#
# Evaluation:
# 2018-05-18T14:17:11.109567: step 13800, loss 0.2927, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-13800
#
#
# Evaluation:
# 2018-05-18T14:17:55.017132: step 14000, loss 0.297219, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-14000
#
#
# Evaluation:
# 2018-05-18T14:18:38.274466: step 14200, loss 0.254527, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-14200
#
#
# Evaluation:
# 2018-05-18T14:19:21.697395: step 14400, loss 0.245739, acc 0.92
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-14400
#
#
# Evaluation:
# 2018-05-18T14:20:05.077740: step 14600, loss 0.398438, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-14600
#
#
# Evaluation:
# 2018-05-18T14:20:48.445873: step 14800, loss 0.411337, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-14800
#
#
# Evaluation:
# 2018-05-18T14:21:31.917409: step 15000, loss 0.351365, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-15000
#
#
# Evaluation:
# 2018-05-18T14:22:15.045955: step 15200, loss 0.359452, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-15200
#
#
# Evaluation:
# 2018-05-18T14:22:58.433697: step 15400, loss 0.511903, acc 0.8
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-15400
#
#
# Evaluation:
# 2018-05-18T14:23:41.872041: step 15600, loss 0.329957, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-15600
#
#
# Evaluation:
# 2018-05-18T14:24:25.182166: step 15800, loss 0.4664, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-15800
#
#
# Evaluation:
# 2018-05-18T14:25:08.605121: step 16000, loss 0.299401, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-16000
#
#
# Evaluation:
# 2018-05-18T14:25:53.809079: step 16200, loss 0.26264, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-16200
#
#
# Evaluation:
# 2018-05-18T14:26:37.679999: step 16400, loss 0.30923, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-16400
#
#
# Evaluation:
# 2018-05-18T14:27:21.192537: step 16600, loss 0.488763, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-16600
#
#
# Evaluation:
# 2018-05-18T14:28:04.606673: step 16800, loss 0.31015, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-16800
#
#
# Evaluation:
# 2018-05-18T14:28:48.017416: step 17000, loss 0.333984, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-17000
#
#
# Evaluation:
# 2018-05-18T14:29:31.780373: step 17200, loss 0.318434, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-17200
#
#
# Evaluation:
# 2018-05-18T14:30:15.089714: step 17400, loss 0.427953, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-17400
#
#
# Evaluation:
# 2018-05-18T14:30:58.776059: step 17600, loss 0.386083, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-17600
#
#
# Evaluation:
# 2018-05-18T14:31:42.076003: step 17800, loss 0.339837, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-17800
#
#
# Evaluation:
# 2018-05-18T14:32:25.348333: step 18000, loss 0.360191, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-18000
#
#
# Evaluation:
# 2018-05-18T14:33:08.865488: step 18200, loss 0.367302, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-18200
#
#
# Evaluation:
# 2018-05-18T14:33:52.268438: step 18400, loss 0.375196, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-18400
#
#
# Evaluation:
# 2018-05-18T14:34:35.506973: step 18600, loss 0.296422, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-18600
#
#
# Evaluation:
# 2018-05-18T14:35:19.066108: step 18800, loss 0.402803, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-18800
#
#
# Evaluation:
# 2018-05-18T14:36:02.612269: step 19000, loss 0.234245, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-19000
#
#
# Evaluation:
# 2018-05-18T14:36:46.087016: step 19200, loss 0.293471, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-19200
#
#
# Evaluation:
# 2018-05-18T14:37:29.541942: step 19400, loss 0.323215, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-19400
#
#
# Evaluation:
# 2018-05-18T14:38:12.887682: step 19600, loss 0.258765, acc 0.92
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-19600
#
#
# Evaluation:
# 2018-05-18T14:38:56.299421: step 19800, loss 0.248583, acc 0.91
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-19800
#
#
# Evaluation:
# 2018-05-18T14:39:39.678973: step 20000, loss 0.322501, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-20000
#
#
# Evaluation:
# 2018-05-18T14:40:22.929918: step 20200, loss 0.282025, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-20200
#
#
# Evaluation:
# 2018-05-18T14:41:06.322665: step 20400, loss 0.491447, acc 0.8
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-20400
#
#
# Evaluation:
# 2018-05-18T14:41:49.699014: step 20600, loss 0.329604, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-20600
#
#
# Evaluation:
# 2018-05-18T14:42:32.926747: step 20800, loss 0.275708, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-20800
#
#
# Evaluation:
# 2018-05-18T14:43:16.275482: step 21000, loss 0.312919, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-21000
#
#
# Evaluation:
# 2018-05-18T14:43:59.741228: step 21200, loss 0.292699, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-21200
#
#
# Evaluation:
# 2018-05-18T14:44:43.074368: step 21400, loss 0.322817, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-21400
#
#
# Evaluation:
# 2018-05-18T14:45:26.411120: step 21600, loss 0.288866, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-21600
#
#
# Evaluation:
# 2018-05-18T14:46:10.022655: step 21800, loss 0.236096, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-21800
#
#
# Evaluation:
# 2018-05-18T14:46:53.422635: step 22000, loss 0.327545, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-22000
#
#
# Evaluation:
# 2018-05-18T14:47:36.793371: step 22200, loss 0.289803, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-22200
#
#
# Evaluation:
# 2018-05-18T14:48:20.285115: step 22400, loss 0.388272, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-22400
#
#
# Evaluation:
# 2018-05-18T14:49:03.693867: step 22600, loss 0.367885, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-22600
#
#
# Evaluation:
# 2018-05-18T14:49:47.108817: step 22800, loss 0.498869, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-22800
#
#
# Evaluation:
# 2018-05-18T14:50:30.539975: step 23000, loss 0.391922, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-23000
#
#
# Evaluation:
# 2018-05-18T14:51:14.270728: step 23200, loss 0.296949, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-23200
#
#
# Evaluation:
# 2018-05-18T14:51:57.821290: step 23400, loss 0.30589, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-23400
#
#
# Evaluation:
# 2018-05-18T14:52:41.228447: step 23600, loss 0.343408, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-23600
#
#
# Evaluation:
# 2018-05-18T14:53:24.649199: step 23800, loss 0.26491, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-23800
#
#
# Evaluation:
# 2018-05-18T14:54:08.007948: step 24000, loss 0.289992, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-24000
#
#
# Evaluation:
# 2018-05-18T14:54:51.586503: step 24200, loss 0.253503, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-24200
#
#
# Evaluation:
# 2018-05-18T14:55:35.194059: step 24400, loss 0.24045, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-24400
#
#
# Evaluation:
# 2018-05-18T14:56:20.190802: step 24600, loss 0.278728, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-24600
#
#
# Evaluation:
# 2018-05-18T14:57:03.614352: step 24800, loss 0.285037, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-24800
#
#
# Evaluation:
# 2018-05-18T14:57:47.121524: step 25000, loss 0.412317, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-25000
#
#
# Evaluation:
# 2018-05-18T14:58:30.539677: step 25200, loss 0.32806, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-25200
#
#
# Evaluation:
# 2018-05-18T14:59:14.071824: step 25400, loss 0.304134, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-25400
#
#
# Evaluation:
# 2018-05-18T14:59:57.847777: step 25600, loss 0.293864, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-25600
#
#
# Evaluation:
# 2018-05-18T15:00:41.230536: step 25800, loss 0.339239, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-25800
#
#
# Evaluation:
# 2018-05-18T15:01:24.980273: step 26000, loss 0.328752, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-26000
#
#
# Evaluation:
# 2018-05-18T15:02:08.391835: step 26200, loss 0.261382, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-26200
#
#
# Evaluation:
# 2018-05-18T15:02:51.831382: step 26400, loss 0.318861, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-26400
#
#
# Evaluation:
# 2018-05-18T15:03:35.168531: step 26600, loss 0.268826, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-26600
#
#
# Evaluation:
# 2018-05-18T15:04:18.423467: step 26800, loss 0.325074, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-26800
#
#
# Evaluation:
# 2018-05-18T15:05:01.780018: step 27000, loss 0.330041, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-27000
#
#
# Evaluation:
# 2018-05-18T15:05:45.191369: step 27200, loss 0.269476, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-27200
#
#
# Evaluation:
# 2018-05-18T15:06:28.773713: step 27400, loss 0.350896, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-27400
#
#
# Evaluation:
# 2018-05-18T15:07:12.225868: step 27600, loss 0.325685, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-27600
#
#
# Evaluation:
# 2018-05-18T15:07:55.664608: step 27800, loss 0.313396, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-27800
#
#
# Evaluation:
# 2018-05-18T15:08:39.065166: step 28000, loss 0.315927, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-28000
#
#
# Evaluation:
# 2018-05-18T15:09:22.551086: step 28200, loss 0.308195, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-28200
#
#
# Evaluation:
# 2018-05-18T15:10:05.908024: step 28400, loss 0.317934, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-28400
#
#
# Evaluation:
# 2018-05-18T15:10:49.491385: step 28600, loss 0.297526, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-28600
#
#
# Evaluation:
# 2018-05-18T15:11:33.106338: step 28800, loss 0.280598, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-28800
#
#
# Evaluation:
# 2018-05-18T15:12:16.475885: step 29000, loss 0.27095, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-29000
#
#
# Evaluation:
# 2018-05-18T15:12:59.860226: step 29200, loss 0.263642, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-29200
#
#
# Evaluation:
# 2018-05-18T15:13:43.418771: step 29400, loss 0.539272, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-29400
#
#
# Evaluation:
# 2018-05-18T15:14:26.866335: step 29600, loss 0.300471, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-29600
#
#
# Evaluation:
# 2018-05-18T15:15:10.345884: step 29800, loss 0.264657, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-29800
#
#
# Evaluation:
# 2018-05-18T15:15:53.930017: step 30000, loss 0.489092, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-30000
#
#
# Evaluation:
# 2018-05-18T15:16:37.555776: step 30200, loss 0.405515, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-30200
#
#
# Evaluation:
# 2018-05-18T15:17:20.974119: step 30400, loss 0.404033, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-30400
#
#
# Evaluation:
# 2018-05-18T15:18:04.542458: step 30600, loss 0.295352, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-30600
#
#
# Evaluation:
# 2018-05-18T15:18:48.015808: step 30800, loss 0.611221, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-30800
#
#
# Evaluation:
# 2018-05-18T15:19:31.419538: step 31000, loss 0.3302, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-31000
#
#
# Evaluation:
# 2018-05-18T15:20:14.974091: step 31200, loss 0.291826, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-31200
#
#
# Evaluation:
# 2018-05-18T15:20:58.589234: step 31400, loss 0.281962, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-31400
#
#
# Evaluation:
# 2018-05-18T15:21:41.942164: step 31600, loss 0.350902, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-31600
#
#
# Evaluation:
# 2018-05-18T15:22:25.495113: step 31800, loss 0.368433, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-31800
#
#
# Evaluation:
# 2018-05-18T15:23:09.045261: step 32000, loss 0.405378, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-32000
#
#
# Evaluation:
# 2018-05-18T15:23:52.463625: step 32200, loss 0.293223, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-32200
#
#
# Evaluation:
# 2018-05-18T15:24:35.869968: step 32400, loss 0.305008, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-32400
#
#
# Evaluation:
# 2018-05-18T15:25:19.418296: step 32600, loss 0.341673, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-32600
#
#
# Evaluation:
# 2018-05-18T15:26:06.510094: step 32800, loss 0.317341, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-32800
#
#
# Evaluation:
# 2018-05-18T15:26:55.993680: step 33000, loss 0.320188, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-33000
#
#
# Evaluation:
# 2018-05-18T15:27:44.103868: step 33200, loss 0.466822, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-33200
#
#
# Evaluation:
# 2018-05-18T15:28:32.149043: step 33400, loss 0.387848, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-33400
#
#
# Evaluation:
# 2018-05-18T15:29:19.785420: step 33600, loss 0.349569, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-33600
#
#
# Evaluation:
# 2018-05-18T15:30:03.304178: step 33800, loss 0.29129, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-33800
#
#
# Evaluation:
# 2018-05-18T15:30:46.796930: step 34000, loss 0.298802, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-34000
#
#
# Evaluation:
# 2018-05-18T15:31:30.560090: step 34200, loss 0.333868, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-34200
#
#
# Evaluation:
# 2018-05-18T15:32:13.965639: step 34400, loss 0.383032, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-34400
#
#
# Evaluation:
# 2018-05-18T15:32:57.556988: step 34600, loss 0.399065, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-34600
#
#
# Evaluation:
# 2018-05-18T15:33:41.083733: step 34800, loss 0.435567, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-34800
#
#
# Evaluation:
# 2018-05-18T15:34:24.574494: step 35000, loss 0.442679, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-35000
#
#
# Evaluation:
# 2018-05-18T15:35:08.121056: step 35200, loss 0.398125, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-35200
#
#
# Evaluation:
# 2018-05-18T15:35:51.636201: step 35400, loss 0.389637, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-35400
#
#
# Evaluation:
# 2018-05-18T15:36:35.315749: step 35600, loss 0.339391, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-35600
#
#
# Evaluation:
# 2018-05-18T15:37:18.948095: step 35800, loss 0.441253, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-35800
#
#
# Evaluation:
# 2018-05-18T15:38:02.513658: step 36000, loss 0.323702, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-36000
#
#
# Evaluation:
# 2018-05-18T15:38:45.960619: step 36200, loss 0.389846, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-36200
#
#
# Evaluation:
# 2018-05-18T15:39:29.336364: step 36400, loss 0.528187, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-36400
#
#
# Evaluation:
# 2018-05-18T15:40:12.886706: step 36600, loss 0.335573, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-36600
#
#
# Evaluation:
# 2018-05-18T15:40:56.121448: step 36800, loss 0.384941, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-36800
#
#
# Evaluation:
# 2018-05-18T15:41:39.759182: step 37000, loss 0.355375, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-37000
#
#
# Evaluation:
# 2018-05-18T15:42:23.118543: step 37200, loss 0.341279, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-37200
#
#
# Evaluation:
# 2018-05-18T15:43:06.585902: step 37400, loss 0.305641, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-37400
#
#
# Evaluation:
# 2018-05-18T15:43:50.079663: step 37600, loss 0.402984, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-37600
#
#
# Evaluation:
# 2018-05-18T15:44:33.537827: step 37800, loss 0.301121, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-37800
#
#
# Evaluation:
# 2018-05-18T15:45:16.928380: step 38000, loss 0.358635, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-38000
#
#
# Evaluation:
# 2018-05-18T15:46:00.499119: step 38200, loss 0.342576, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-38200
#
#
# Evaluation:
# 2018-05-18T15:46:43.850669: step 38400, loss 0.403435, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-38400
#
#
# Evaluation:
# 2018-05-18T15:47:27.196021: step 38600, loss 0.302545, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-38600
#
#
# Evaluation:
# 2018-05-18T15:48:10.678781: step 38800, loss 0.287142, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-38800
#
#
# Evaluation:
# 2018-05-18T15:48:53.950926: step 39000, loss 0.434752, acc 0.8
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-39000
#
#
# Evaluation:
# 2018-05-18T15:49:37.388869: step 39200, loss 0.353467, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-39200
#
#
# Evaluation:
# 2018-05-18T15:50:20.744420: step 39400, loss 0.366687, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-39400
#
#
# Evaluation:
# 2018-05-18T15:51:04.190376: step 39600, loss 0.36159, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-39600
#
#
# Evaluation:
# 2018-05-18T15:51:47.713135: step 39800, loss 0.434623, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-39800
#
#
# Evaluation:
# 2018-05-18T15:52:31.164880: step 40000, loss 0.377549, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-40000
#
#
# Evaluation:
# 2018-05-18T15:53:14.605634: step 40200, loss 0.395358, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-40200
#
#
# Evaluation:
# 2018-05-18T15:53:57.997975: step 40400, loss 0.320046, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-40400
#
#
# Evaluation:
# 2018-05-18T15:54:41.474748: step 40600, loss 0.314075, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-40600
#
#
# Evaluation:
# 2018-05-18T15:55:24.904911: step 40800, loss 0.326663, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-40800
#
#
# Evaluation:
# 2018-05-18T15:56:09.306482: step 41000, loss 0.334371, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-41000
#
#
# Evaluation:
# 2018-05-18T15:56:53.339442: step 41200, loss 0.368314, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-41200
#
#
# Evaluation:
# 2018-05-18T15:57:36.941386: step 41400, loss 0.327529, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-41400
#
#
# Evaluation:
# 2018-05-18T15:58:20.443332: step 41600, loss 0.358841, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-41600
#
#
# Evaluation:
# 2018-05-18T15:59:03.905066: step 41800, loss 0.332453, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-41800
#
#
# Evaluation:
# 2018-05-18T15:59:47.097615: step 42000, loss 0.60208, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-42000
#
#
# Evaluation:
# 2018-05-18T16:00:30.663368: step 42200, loss 0.344082, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-42200
#
#
# Evaluation:
# 2018-05-18T16:01:14.231723: step 42400, loss 0.353404, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-42400
#
#
# Evaluation:
# 2018-05-18T16:01:57.666472: step 42600, loss 0.511684, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-42600
#
#
# Evaluation:
# 2018-05-18T16:02:41.149224: step 42800, loss 0.409664, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-42800
#
#
# Evaluation:
# 2018-05-18T16:03:24.563588: step 43000, loss 0.548235, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-43000
#
#
# Evaluation:
# 2018-05-18T16:04:07.968534: step 43200, loss 0.38984, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-43200
#
#
# Evaluation:
# 2018-05-18T16:04:51.536273: step 43400, loss 0.428754, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-43400
#
#
# Evaluation:
# 2018-05-18T16:05:34.905820: step 43600, loss 0.470429, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-43600
#
#
# Evaluation:
# 2018-05-18T16:06:18.544374: step 43800, loss 0.331247, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-43800
#
#
# Evaluation:
# 2018-05-18T16:07:02.040324: step 44000, loss 0.470032, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-44000
#
#
# Evaluation:
# 2018-05-18T16:07:45.716880: step 44200, loss 0.390521, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-44200
#
#
# Evaluation:
# 2018-05-18T16:08:29.140620: step 44400, loss 0.30171, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-44400
#
#
# Evaluation:
# 2018-05-18T16:09:12.858980: step 44600, loss 0.29396, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-44600
#
#
# Evaluation:
# 2018-05-18T16:09:56.563943: step 44800, loss 0.372383, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-44800
#
#
# Evaluation:
# 2018-05-18T16:10:40.470887: step 45000, loss 0.340132, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-45000
#
#
# Evaluation:
# 2018-05-18T16:11:24.102660: step 45200, loss 0.40139, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-45200
#
#
# Evaluation:
# 2018-05-18T16:12:07.582006: step 45400, loss 0.329026, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-45400
#
#
# Evaluation:
# 2018-05-18T16:12:51.063965: step 45600, loss 0.43115, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-45600
#
#
# Evaluation:
# 2018-05-18T16:13:34.353912: step 45800, loss 0.366493, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-45800
#
#
# Evaluation:
# 2018-05-18T16:14:17.716674: step 46000, loss 0.579403, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-46000
#
#
# Evaluation:
# 2018-05-18T16:15:01.089601: step 46200, loss 0.513905, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-46200
#
#
# Evaluation:
# 2018-05-18T16:15:44.539967: step 46400, loss 0.407429, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-46400
#
#
# Evaluation:
# 2018-05-18T16:16:28.356328: step 46600, loss 0.427578, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-46600
#
#
# Evaluation:
# 2018-05-18T16:17:11.758274: step 46800, loss 0.338612, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-46800
#
#
# Evaluation:
# 2018-05-18T16:17:55.050825: step 47000, loss 0.387354, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-47000
#
#
# Evaluation:
# 2018-05-18T16:18:38.474190: step 47200, loss 0.350128, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-47200
#
#
# Evaluation:
# 2018-05-18T16:19:21.879157: step 47400, loss 0.445756, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-47400
#
#
# Evaluation:
# 2018-05-18T16:20:05.363917: step 47600, loss 0.461261, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-47600
#
#
# Evaluation:
# 2018-05-18T16:20:48.746849: step 47800, loss 0.417411, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-47800
#
#
# Evaluation:
# 2018-05-18T16:21:32.137802: step 48000, loss 0.498356, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-48000
#
#
# Evaluation:
# 2018-05-18T16:22:15.546985: step 48200, loss 0.353828, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-48200
#
#
# Evaluation:
# 2018-05-18T16:22:58.930934: step 48400, loss 0.41669, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-48400
#
#
# Evaluation:
# 2018-05-18T16:23:42.389490: step 48600, loss 0.458316, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-48600
#
#
# Evaluation:
# 2018-05-18T16:24:25.742247: step 48800, loss 0.414549, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-48800
#
#
# Evaluation:
# 2018-05-18T16:25:09.163806: step 49000, loss 0.360387, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-49000
#
#
# Evaluation:
# 2018-05-18T16:25:54.414999: step 49200, loss 0.414362, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-49200
#
#
# Evaluation:
# 2018-05-18T16:26:39.979576: step 49400, loss 0.424554, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-49400
#
#
# Evaluation:
# 2018-05-18T16:27:23.588930: step 49600, loss 0.444969, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-49600
#
#
# Evaluation:
# 2018-05-18T16:28:07.130276: step 49800, loss 0.386185, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-49800
#
#
# Evaluation:
# 2018-05-18T16:28:50.763040: step 50000, loss 0.393694, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-50000
#
#
# Evaluation:
# 2018-05-18T16:29:34.223588: step 50200, loss 0.705981, acc 0.79
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-50200
#
#
# Evaluation:
# 2018-05-18T16:30:17.870966: step 50400, loss 0.341564, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-50400
#
#
# Evaluation:
# 2018-05-18T16:31:01.367296: step 50600, loss 0.567019, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-50600
#
#
# Evaluation:
# 2018-05-18T16:31:45.125654: step 50800, loss 0.62593, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-50800
#
#
# Evaluation:
# 2018-05-18T16:32:28.671818: step 51000, loss 0.400285, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-51000
#
#
# Evaluation:
# 2018-05-18T16:33:12.163553: step 51200, loss 0.404388, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-51200
#
#
# Evaluation:
# 2018-05-18T16:33:55.687101: step 51400, loss 0.452068, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-51400
#
#
# Evaluation:
# 2018-05-18T16:34:39.145864: step 51600, loss 0.397188, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-51600
#
#
# Evaluation:
# 2018-05-18T16:35:22.738617: step 51800, loss 0.433362, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-51800
#
#
# Evaluation:
# 2018-05-18T16:36:06.426976: step 52000, loss 0.39792, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-52000
#
#
# Evaluation:
# 2018-05-18T16:36:49.981736: step 52200, loss 0.54172, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-52200
#
#
# Evaluation:
# 2018-05-18T16:37:33.593292: step 52400, loss 0.556263, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-52400
#
#
# Evaluation:
# 2018-05-18T16:38:17.271267: step 52600, loss 0.528053, acc 0.8
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-52600
#
#
# Evaluation:
# 2018-05-18T16:39:00.849830: step 52800, loss 0.36794, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-52800
#
#
# Evaluation:
# 2018-05-18T16:39:44.387395: step 53000, loss 0.345942, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-53000
#
#
# Evaluation:
# 2018-05-18T16:40:27.943147: step 53200, loss 0.389116, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-53200
#
#
# Evaluation:
# 2018-05-18T16:41:11.605909: step 53400, loss 0.416905, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-53400
#
#
# Evaluation:
# 2018-05-18T16:41:55.199649: step 53600, loss 0.352378, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-53600
#
#
# Evaluation:
# 2018-05-18T16:42:38.638205: step 53800, loss 0.338393, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-53800
#
#
# Evaluation:
# 2018-05-18T16:43:22.234747: step 54000, loss 0.520028, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-54000
#
#
# Evaluation:
# 2018-05-18T16:44:05.781309: step 54200, loss 0.404397, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-54200
#
#
# Evaluation:
# 2018-05-18T16:44:49.296847: step 54400, loss 0.331, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-54400
#
#
# Evaluation:
# 2018-05-18T16:45:32.818213: step 54600, loss 0.507045, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-54600
#
#
# Evaluation:
# 2018-05-18T16:46:16.620194: step 54800, loss 0.427552, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-54800
#
#
# Evaluation:
# 2018-05-18T16:47:00.150155: step 55000, loss 0.361916, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-55000
#
#
# Evaluation:
# 2018-05-18T16:47:43.636092: step 55200, loss 0.388553, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-55200
#
#
# Evaluation:
# 2018-05-18T16:48:27.155256: step 55400, loss 0.378637, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-55400
#
#
# Evaluation:
# 2018-05-18T16:49:10.768209: step 55600, loss 0.388631, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-55600
#
#
# Evaluation:
# 2018-05-18T16:49:54.331771: step 55800, loss 0.423964, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-55800
#
#
# Evaluation:
# 2018-05-18T16:50:37.835524: step 56000, loss 0.367472, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-56000
#
#
# Evaluation:
# 2018-05-18T16:51:21.573057: step 56200, loss 0.47878, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-56200
#
#
# Evaluation:
# 2018-05-18T16:52:05.331437: step 56400, loss 0.375883, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-56400
#
#
# Evaluation:
# 2018-05-18T16:52:48.800571: step 56600, loss 0.378729, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-56600
#
#
# Evaluation:
# 2018-05-18T16:53:32.347538: step 56800, loss 0.371832, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-56800
#
#
# Evaluation:
# 2018-05-18T16:54:15.807517: step 57000, loss 0.645803, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-57000
#
#
# Evaluation:
# 2018-05-18T16:54:59.226261: step 57200, loss 0.391167, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-57200
#
#
# Evaluation:
# 2018-05-18T16:55:42.780633: step 57400, loss 0.469773, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-57400
#
#
# Evaluation:
# 2018-05-18T16:56:27.702006: step 57600, loss 0.576784, acc 0.81
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-57600
#
#
# Evaluation:
# 2018-05-18T16:57:11.293570: step 57800, loss 0.512504, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-57800
#
#
# Evaluation:
# 2018-05-18T16:57:54.803336: step 58000, loss 0.568729, acc 0.82
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-58000
#
#
# Evaluation:
# 2018-05-18T16:58:38.298291: step 58200, loss 0.491716, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-58200
#
#
# Evaluation:
# 2018-05-18T16:59:21.866241: step 58400, loss 0.445648, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-58400
#
#
# Evaluation:
# 2018-05-18T17:00:05.424390: step 58600, loss 0.338043, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-58600
#
#
# Evaluation:
# 2018-05-18T17:00:49.003927: step 58800, loss 0.368508, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-58800
#
#
# Evaluation:
# 2018-05-18T17:01:32.628885: step 59000, loss 0.361673, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-59000
#
#
# Evaluation:
# 2018-05-18T17:02:16.306040: step 59200, loss 0.330079, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-59200
#
#
# Evaluation:
# 2018-05-18T17:03:00.169413: step 59400, loss 0.352502, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-59400
#
#
# Evaluation:
# 2018-05-18T17:03:43.836576: step 59600, loss 0.339426, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-59600
#
#
# Evaluation:
# 2018-05-18T17:04:27.371740: step 59800, loss 0.441661, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-59800
#
#
# Evaluation:
# ...
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-516000
#
#
# Evaluation:
# 2018-05-31T14:21:52.104778: step 516200, loss 0.430954, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-516200
#
#
# Evaluation:
# 2018-05-31T14:22:36.273608: step 516400, loss 0.415098, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-516400
#
#
# Evaluation:
# 2018-05-31T14:23:20.528038: step 516600, loss 0.546847, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-516600
#
#
# Evaluation:
# 2018-05-31T14:24:04.754707: step 516800, loss 0.527724, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-516800
#
#
# Evaluation:
# 2018-05-31T14:24:48.774740: step 517000, loss 0.441926, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-517000
#
#
# Evaluation:
# 2018-05-31T14:25:32.921370: step 517200, loss 0.424763, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-517200
#
#
# Evaluation:
# 2018-05-31T14:26:17.027205: step 517400, loss 0.544156, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-517400
#
#
# Evaluation:
# 2018-05-31T14:27:03.572050: step 517600, loss 0.457815, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-517600
#
#
# Evaluation:
# 2018-05-31T14:27:47.895475: step 517800, loss 0.560358, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-517800
#
#
# Evaluation:
# 2018-05-31T14:28:32.280321: step 518000, loss 0.575491, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-518000
#
#
# Evaluation:
# 2018-05-31T14:29:16.393161: step 518200, loss 0.510305, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-518200
#
#
# Evaluation:
# 2018-05-31T14:30:00.568396: step 518400, loss 0.454035, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-518400
#
#
# Evaluation:
# 2018-05-31T14:30:44.788044: step 518600, loss 0.544388, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-518600
#
#
# Evaluation:
# 2018-05-31T14:31:28.996281: step 518800, loss 0.425003, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-518800
#
#
# Evaluation:
# 2018-05-31T14:32:13.197932: step 519000, loss 0.523807, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-519000
#
#
# Evaluation:
# 2018-05-31T14:32:57.351963: step 519200, loss 0.452476, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-519200
#
#
# Evaluation:
# 2018-05-31T14:33:41.507995: step 519400, loss 0.407029, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-519400
#
#
# Evaluation:
# 2018-05-31T14:34:25.626831: step 519600, loss 0.433154, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-519600
#
#
# Evaluation:
# 2018-05-31T14:35:09.855268: step 519800, loss 0.415008, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-519800
#
#
# Evaluation:
# 2018-05-31T14:35:53.908302: step 520000, loss 0.536611, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-520000
#
#
# Evaluation:
# 2018-05-31T14:36:38.277350: step 520200, loss 0.738722, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-520200
#
#
# Evaluation:
# 2018-05-31T14:37:23.352202: step 520400, loss 0.786735, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-520400
#
#
# Evaluation:
# 2018-05-31T14:38:07.574052: step 520600, loss 0.536275, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-520600
#
#
# Evaluation:
# 2018-05-31T14:38:51.592684: step 520800, loss 0.524292, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-520800
#
#
# Evaluation:
# 2018-05-31T14:39:35.699717: step 521000, loss 0.559978, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-521000
#
#
# Evaluation:
# 2018-05-31T14:40:19.707947: step 521200, loss 0.568958, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-521200
#
#
# Evaluation:
# 2018-05-31T14:41:04.932591: step 521400, loss 0.421388, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-521400
#
#
# Evaluation:
# 2018-05-31T14:41:49.211225: step 521600, loss 0.472615, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-521600
#
#
# Evaluation:
# 2018-05-31T14:42:33.428872: step 521800, loss 0.472158, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-521800
#
#
# Evaluation:
# 2018-05-31T14:43:17.430313: step 522000, loss 0.413987, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-522000
#
#
# Evaluation:
# 2018-05-31T14:44:01.581534: step 522200, loss 0.408835, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-522200
#
#
# Evaluation:
# 2018-05-31T14:44:45.631164: step 522400, loss 0.476631, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-522400
#
#
# Evaluation:
# 2018-05-31T14:45:29.696393: step 522600, loss 0.429888, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-522600
#
#
# Evaluation:
# 2018-05-31T14:46:13.943231: step 522800, loss 0.524109, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-522800
#
#
# Evaluation:
# 2018-05-31T14:46:58.209675: step 523000, loss 0.389959, acc 0.91
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-523000
#
#
# Evaluation:
# 2018-05-31T14:47:43.166118: step 523200, loss 0.423285, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-523200
#
#
# Evaluation:
# 2018-05-31T14:48:27.632965: step 523400, loss 0.462621, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-523400
#
#
# Evaluation:
# 2018-05-31T14:49:11.586003: step 523600, loss 0.53685, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-523600
#
#
# Evaluation:
# 2018-05-31T14:49:55.469441: step 523800, loss 0.682846, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-523800
#
#
# Evaluation:
# 2018-05-31T14:50:39.635073: step 524000, loss 0.457167, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-524000
#
#
# Evaluation:
# 2018-05-31T14:51:23.858117: step 524200, loss 0.45277, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-524200
#
#
# Evaluation:
# 2018-05-31T14:52:07.906768: step 524400, loss 0.39902, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-524400
#
#
# Evaluation:
# 2018-05-31T14:52:51.945211: step 524600, loss 0.553854, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-524600
#
#
# Evaluation:
# 2018-05-31T14:53:35.963644: step 524800, loss 0.405949, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-524800
#
#
# Evaluation:
# 2018-05-31T14:54:20.153471: step 525000, loss 0.503427, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-525000
#
#
# Evaluation:
# 2018-05-31T14:55:04.286704: step 525200, loss 0.586818, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-525200
#
#
# Evaluation:
# 2018-05-31T14:55:48.354937: step 525400, loss 0.465456, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-525400
#
#
# Evaluation:
# 2018-05-31T14:56:32.698971: step 525600, loss 0.386753, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-525600
#
#
# Evaluation:
# 2018-05-31T14:57:16.699611: step 525800, loss 0.701672, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-525800
#
#
# Evaluation:
# 2018-05-31T14:58:01.029441: step 526000, loss 0.494638, acc 0.83
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-526000
#
#
# Evaluation:
# 2018-05-31T14:58:45.117684: step 526200, loss 0.437223, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-526200
#
#
# Evaluation:
# 2018-05-31T14:59:29.170525: step 526400, loss 0.484849, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-526400
#
#
# Evaluation:
# 2018-05-31T15:00:13.433752: step 526600, loss 0.422114, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-526600
#
#
# Evaluation:
# 2018-05-31T15:00:57.545980: step 526800, loss 0.37945, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-526800
#
#
# Evaluation:
# 2018-05-31T15:01:41.799608: step 527000, loss 0.439319, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-527000
#
#
# Evaluation:
# 2018-05-31T15:02:26.002043: step 527200, loss 0.708723, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-527200
#
#
# Evaluation:
# 2018-05-31T15:03:09.978681: step 527400, loss 0.391248, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-527400
#
#
# Evaluation:
# 2018-05-31T15:03:54.147929: step 527600, loss 0.461636, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-527600
#
#
# Evaluation:
# 2018-05-31T15:04:38.249984: step 527800, loss 0.621518, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-527800
#
#
# Evaluation:
# 2018-05-31T15:05:22.345219: step 528000, loss 0.427272, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-528000
#
#
# Evaluation:
# 2018-05-31T15:06:06.359846: step 528200, loss 0.396083, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-528200
#
#
# Evaluation:
# 2018-05-31T15:06:50.598089: step 528400, loss 0.463686, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-528400
#
#
# Evaluation:
# 2018-05-31T15:07:34.503546: step 528600, loss 0.370873, acc 0.91
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-528600
#
#
# Evaluation:
# 2018-05-31T15:08:18.719379: step 528800, loss 0.455259, acc 0.9
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-528800
#
#
# Evaluation:
# 2018-05-31T15:09:02.801406: step 529000, loss 0.520112, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-529000
#
#
# Evaluation:
# 2018-05-31T15:09:47.408037: step 529200, loss 0.518122, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-529200
#
#
# Evaluation:
# 2018-05-31T15:10:32.782686: step 529400, loss 0.507163, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-529400
#
#
# Evaluation:
# 2018-05-31T15:11:23.839581: step 529600, loss 0.597474, acc 0.84
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-529600
#
#
# Evaluation:
# 2018-05-31T15:12:12.901091: step 529800, loss 0.475128, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-529800
#
#
# Evaluation:
# 2018-05-31T15:13:01.947190: step 530000, loss 0.402692, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-530000
#
#
# Evaluation:
# 2018-05-31T15:13:50.875490: step 530200, loss 0.410856, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-530200
#
#
# Evaluation:
# 2018-05-31T15:14:35.267535: step 530400, loss 0.413687, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-530400
#
#
# Evaluation:
# 2018-05-31T15:15:19.449569: step 530600, loss 0.621904, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-530600
#
#
# Evaluation:
# 2018-05-31T15:16:03.881603: step 530800, loss 0.408207, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-530800
#
#
# Evaluation:
# 2018-05-31T15:16:48.280244: step 531000, loss 0.391054, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-531000
#
#
# Evaluation:
# 2018-05-31T15:17:33.231502: step 531200, loss 0.37795, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-531200
#
#
# Evaluation:
# 2018-05-31T15:18:17.409759: step 531400, loss 0.51651, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-531400
#
#
# Evaluation:
# 2018-05-31T15:19:02.454397: step 531600, loss 0.437129, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-531600
#
#
# Evaluation:
# 2018-05-31T15:19:46.629422: step 531800, loss 0.38858, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-531800
#
#
# Evaluation:
# 2018-05-31T15:20:30.706462: step 532000, loss 0.504454, acc 0.85
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-532000
#
#
# Evaluation:
# 2018-05-31T15:21:14.786920: step 532200, loss 0.410812, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-532200
#
#
# Evaluation:
# 2018-05-31T15:21:58.972148: step 532400, loss 0.485866, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-532400
#
#
# Evaluation:
# 2018-05-31T15:22:43.066167: step 532600, loss 0.512315, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-532600
#
#
# Evaluation:
# 2018-05-31T15:23:27.223199: step 532800, loss 0.515635, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-532800
#
#
# Evaluation:
# 2018-05-31T15:24:11.419849: step 533000, loss 0.494115, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-533000
#
#
# Evaluation:
# 2018-05-31T15:24:55.364292: step 533200, loss 0.485733, acc 0.91
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-533200
#
#
# Evaluation:
# 2018-05-31T15:25:39.466924: step 533400, loss 0.417564, acc 0.91
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-533400
#
#
# Evaluation:
# 2018-05-31T15:26:23.646345: step 533600, loss 0.615614, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-533600
#
#
# Evaluation:
# 2018-05-31T15:27:07.782405: step 533800, loss 0.624459, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-533800
#
#
# Evaluation:
# 2018-05-31T15:27:51.937842: step 534000, loss 0.40922, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-534000
#
#
# Evaluation:
# 2018-05-31T15:28:35.965699: step 534200, loss 0.43999, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-534200
#
#
# Evaluation:
# 2018-05-31T15:29:20.001944: step 534400, loss 0.428031, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-534400
#
#
# Evaluation:
# 2018-05-31T15:30:04.218793: step 534600, loss 0.477504, acc 0.86
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-534600
#
#
# Evaluation:
# 2018-05-31T15:30:48.198617: step 534800, loss 0.415173, acc 0.87
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-534800
#
#
# Evaluation:
# 2018-05-31T15:31:32.345657: step 535000, loss 0.453314, acc 0.88
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-535000
#
#
# Evaluation:
# 2018-05-31T15:32:16.462906: step 535200, loss 0.573141, acc 0.89
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-535200
#
#
# Evaluation:
# 2018-05-31T15:33:00.497552: step 535400, loss 0.485721, acc 0.91
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-535400
#
#
# Evaluation:
# 2018-05-31T15:33:44.633186: step 535600, loss 0.395332, acc 0.91
#
# Saved model checkpoint to D:\emotionTest\runs\1526617599\checkpoints\model-535600

# %%
class Word2Vec(object):
#     word_vec_size = 300
#     window = 5
#     min_count = 2
#     flag = 'W'
    """
    Word2Vec을 이용하여 사전을 만드는 여러가지 방식을 제공
    <Parameters>
        - word_vec_size : 단어 하나당 vector size
        - window : 현재 word를 계산하는데 사용하는 maximum distance
        - min_count : 단어가 해당 개수 이하로 나오면 무시
        - flag : 5가지 종류 제공.
          1) W : mecab 형태소분석 결과 word 단위 word2vec 사전
          2) WT : mecab 형태소분석 결과 word 단위 + pos tagging word2vec 사전
          3) JM : jamo 단위 word2vec 사전
          4) LN : N = 1,2,.. n 글자수 단위 사전 제공
    <Function>
        - make_input(sentence_list) : 각 flag에 알맞은 input 형태를 만들어서 return
        - save_w2v_dic(sentence_list, path) : 각 flag에 알맞은 사전은 원하는 path에 저장
    """
    def __init__(self, word_vec_size=300, window=5, min_count=2, flag='W'):
        self.word_vec_size = word_vec_size
        self.window = window
        self.min_count = min_count
        self.flag = flag
    

    def parse_sentence(self, text, param):
        if type(text) == str:
            text = ''.join(text.split()) #space remove
            words_array = []
            
            if self.flag[0] == 'W':
                mecab = MeCab.Tagger()
                
                parse_result = mecab.parse(text) # pose parse
                info_of_words = parse_result.split('\n')
                
                for info in info_of_words:
                    if not (info == 'EOS' or info == ''):
                        info_elems = info.split(',')
                        posed_word = info_elems[0].split('\t')

                        if param and len(posed_word)>1:
                            words_array.append( posed_word[0]+'/'+posed_word[1])
                        else:
                            words_array.append( posed_word[0])
            elif self.flag == 'JM':
                words_array = list(j2hcj(h2j(text)))
            elif self.flag[0] == 'L':
                n = param
                words_array = [text[i:i+n] for i in range(0, len(text), n)]
                
            return words_array
        else:
            return False
    

    def make_input(self, sentence_list):
        input_x = []
        
        for text in sentence_list:
            if self.flag[0] == 'W':
                if len(self.flag) > 1 and self.flag[1] == 'T':
                    param = True
                else:
                    param = False
            elif self.flag[0] == 'L':
                if len(self.flag) > 1 :
                    param = int(self.flag[1])
            else:
                param = ''
            result = self.parse_sentence(text=text, param=param)
            if type(result)==list and len(result) > 0:
                input_x.extend(result)
        return input_x        
    

    def make_w2v_dic(self, sentence_list):
        if type(sentence_list) == list:
            input_x = self.make_input(sentence_list)
            w2v_input = np.array(input_x)
            model = gensim.models.Word2Vec(min_count=self.min_count, window=self.window, size=self.word_vec_size)
            model.build_vocab(w2v_input)
            model.train(w2v_input, total_examples=model.corpus_count, epochs=model.epochs)
            word_vectors = model.wv

            return model, word_vectors
        else:
            return False
    
    
    def save_w2v_dic(self, sentence_list, path):

        SAVE_PATH = path
        SAVE_NAME = SAVE_PATH+datetime.datetime.now().strftime('%Y%m%d%H%M')+'_'+str(word_vec_size)+'_'+self.flag
        
        model, word_vectors = self.make_w2v_dic(sentence_list)
        print("Dictionary is saved : "+SAVE_NAME)
        model.save(SAVE_NAME+'.bin')

# %%
x_train.shape[2]
# Out:
# int
